# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# -- 2: Matplotlib --
# 1)
def make_sine_wave(x, A, w):
    y = A * np.sin(w * x)
    return y

# 2)
x = np.linspace (0, 2 # np.pi, 1000) 
# This creates an array that goes from 0 to 2pi that has 1000 points

# 3)
